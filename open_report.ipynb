# %% [markdown]
# # 📊 Calibration Benchmarking Study — Final Report
#
# Click the link below to open the interactive HTML report with all plots and tables.

# %%
import os
from IPython.display import display, HTML, FileLink

# ── Locate the report ────────────────────────────────────────────────────────
report_filename = 'calibration_report.html'

# Search order: same folder as this notebook, then current working directory
notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in dir() else os.getcwd()
candidates = [
    os.path.join(notebook_dir, report_filename),
    os.path.join(os.getcwd(),  report_filename),
]

report_path = next((p for p in candidates if os.path.exists(p)), None)

if report_path:
    size_kb = os.path.getsize(report_path) / 1024
    display(HTML(f'''
    <div style="font-family:system-ui,sans-serif;padding:1.25rem 1.5rem;
                background:#f1efe8;border:1px solid #d5d3cc;border-radius:8px;
                max-width:520px">
      <div style="font-size:11px;color:#888;font-family:monospace;
                  text-transform:uppercase;letter-spacing:.1em;margin-bottom:.5rem">
        HTML Report
      </div>
      <a href="{os.path.basename(report_path)}" target="_blank"
         style="font-size:16px;font-weight:600;color:#185fa5;text-decoration:none">
        📄 calibration_report.html
      </a>
      <div style="font-size:12px;color:#666;margin-top:.4rem">
        {size_kb:.0f} KB · self-contained · all 9 plots embedded
      </div>
      <a href="{os.path.basename(report_path)}" target="_blank"
         style="display:inline-block;margin-top:.85rem;padding:.45rem 1.1rem;
                background:#185fa5;color:#fff;border-radius:5px;font-size:13px;
                font-weight:500;text-decoration:none">
        Open Report ↗
      </a>
    </div>
    '''))
else:
    print("calibration_report.html not found.")
    print("Make sure it is in the same folder as this notebook.")
    print(f"Looked in: {notebook_dir}")

# %% [markdown]
# ---
#
# ### How to open
#
# | Environment | How |
# |---|---|
# | **Jupyter / JupyterLab** | Click **Open Report ↗** above, or right-click `calibration_report.html` in the file browser → *Open* |
# | **Google Colab** | Run the cell above — click the link. Or: Files panel → right-click → *Download*, then open locally |
# | **VS Code** | Right-click `calibration_report.html` in Explorer → *Open with Live Server* (or download and open in browser) |
#
# > The HTML file is fully self-contained — all plots are embedded.
# > No internet connection or extra dependencies required.
